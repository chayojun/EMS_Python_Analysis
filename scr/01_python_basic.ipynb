# %% [markdown]
# # 1일차: 데이터 과학과 파이썬 기초 (Why & Basic)

# %%
# 식, 값, 대입연산자, 등위연산자 알아야한다.

name = "파이썬" # 우측값을 좌변 변수에 저장

# 변수: 값, 식(표현식) 2+1, 5, 4>7, True, False
# name == "파이썬"

x = 10
# 10 = 1

# 값 == 값 연산자
5 == 7 # False
9 == 9 # True

3 + 5 == 8 # 8 == 8 True
# x == 9 #변수(표현식) 10 == 9 False

# x == 9 # 변수(표현식)

print("박성환")
print(name)
print("name")
print(x)
x
name?
# Out:
# 박성환
# 파이썬
# name
# 10
# Type:        str
# String form: 파이썬
# Length:      3
# Docstring:
# str(object='') -> str
# str(bytes_or_buffer[, encoding[, errors]]) -> str
#
# Create a new string object from the given object. If encoding or
# errors is specified, then the object must expose a data buffer
# that will be decoded using the given encoding and error handler.
# Otherwise, returns the result of object.__str__() (if defined)
# or repr(object).
# encoding defaults to sys.getdefaultencoding().
# errors defaults to 'strict'.

# %%
# 식, 값, 대입연산자, 등위연산자 알아야한다.

name = "파이썬" # 우측값을 좌변 변수에 저장

# 변수: 값, 식(표현식) 2+1, 5, 4>7, True, False
# name == "파이썬"

x = 10
# 10 = 1

# 값 == 값 연산자
5 == 7 # False
9 == 9 # True

3 + 5 == 8 # 8 == 8 True
# x == 9 #변수(표현식) 10 == 9 False

# x == 9 # 변수(표현식)

print("박성환")
print(name)
print("name")
print(x)
x
name?
# Out:
# 박성환
# 파이썬
# name
# 10
# Type:        str
# String form: 파이썬
# Length:      3
# Docstring:
# str(object='') -> str
# str(bytes_or_buffer[, encoding[, errors]]) -> str
#
# Create a new string object from the given object. If encoding or
# errors is specified, then the object must expose a data buffer
# that will be decoded using the given encoding and error handler.
# Otherwise, returns the result of object.__str__() (if defined)
# or repr(object).
# encoding defaults to sys.getdefaultencoding().
# errors defaults to 'strict'.

# %%
print(name)
# Out:
# 파이썬

# %%
age = 10

# %%
print(age)
# Out:
# 10

# %%
# if 참/거짓
# 참이라는 값 True 과 거짓이라는 값 False

True = 1
# Out:
#   Cell In[6], line 4
#     True = 1
#     ^
# SyntaxError: cannot assign to True

# %%
print(True)
# Out:
# True

# %%
print(3>10)
# Out:
# False

# %%
if False:
    print("test")
print("test2")
# Out:
# test2

# %%
age = 10

if age >= 18:
    print("성인")
else:
    print("미성년자")
# Out:
# 미성년자

# %%
if age >= 18:
    print("성일")

# %%
num = 10
if num > 0:
    print("양수")
    if num % 2 == 0:
            print("짝수")
# Out:
# 양수
# 짝수

# %%
def greet():
    print("안녕하세요")
    print("파이썬입니다")

# %%
# 실수 문자, 데이터프래임(리스트, 딕셔러니)

x = "test"
y = "test"

# %%
z = "test\
hello"

# z = "testhello"

print(z)
# Out:
# testhello

# %%
# True, False, if, else, ...

IF = "test"
print(IF)
# Out:
# test

# %%
if = "test"
# Out:
#   Cell In[17], line 1
#     if = "test"
#        ^
# SyntaxError: invalid syntax

# %%
True = "test"
# Out:
#   Cell In[18], line 1
#     True = "test"
#     ^
# SyntaxError: cannot assign to True

# %%
a_b = 10
print(a_b)
# Out:
# 10

# %%
"""이건 주석"""

s = """이건
문자열"""
print(s)
# Out:
# 이건
# 문자열

# %%
x = 10  # x는 나이값을 저장하는 변수입니다.

age = 10

name = "길동무"

student_name = "저승길"

""" 주석 """

address = "서울특별시\n가산디지털로"
print(address)

job = """운전기사
변호사,판사"""
print(job)
# Out:
# 서울특별시
# 가산디지털로
# 운전기사
# 변호사,판사

# %%
"""주석"""
x = """문자열"""
print(x)
# Out:
# 문자열

# %%
# print(*objects, sep=' ', end='\n', file=None, flush=False) 

print("abc","def", sep = "#", end = "")
print("hello")
# Out:
# abc#defhello

# %%
# f-string 문자열 표현: f""
name = "황천길"
age = 80 + 1
print(f"당신의 이름은 {name} 나이도 {age} 이다") # +연산자 x, ""한번만 사용, 형변형 x
# Out:
# 당신의 이름은 황천길 나이도 81 이다

# %%
test = '안녕"하세요' 
print(test)
# Out:
# 안녕"하세요

# %%
name = "good note"
print(name[0])
# Out:
# g

# %%
name = "good note"
print(name[-1])
# Out:
# e

# %%
name[0] = "G"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 name[0] = "G"
#
# TypeError: 'str' object does not support item assignment

# %%
name = name.replace("g", "G")
name
name = name.replace("n", "N")
name
# Out:
# 'Good Note'

# %%
name2 = name[::] # name.slice(0, 14, 1),  0 = 시작점, 14 = 끝점, 1 = 띄어쓰기
name2
# Out:
# 'Good Note'

# %%
name2[::-1]
# Out:
# 'etoN dooG'

# %%
a = 3.1
print(type(a))

b = "어쩔"
print(type(b))

c = True
print(type(c))
# Out:
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
a = "hello"
a.startswith("he")
"hello".startswith("he")
# Out:
# True

# %%
a = 10
print(type(a))
# Out:
# <class 'int'>

# %%
a = 3.14
print(type(a))
# Out:
# <class 'float'>

# %%
a = "3.14"
print(type(a))
# Out:
# <class 'str'>

# %%
a = True
print(type(a))
# Out:
# <class 'bool'>

# %%
a = 1
b = a
print(b)
# Out:
# 1

# %%
a = 1
b = a
print(a)
print(b)
b = 2
print(a)
print(b)
# Out:
# 1
# 1
# 1
# 2

# %%
a = "abc"
b = a
print(a)
print(b)
b = "xyz"
print(a)
print(b)
# Out:
# abc
# abc
# abc
# xyz

# %%
a = ["루피", "조로", "상디"]
b = a
print(a)
print(b)
# Out:
# ['루피', '조로', '상디']
# ['루피', '조로', '상디']

# %%
print(a[0])
print(b[0])
# Out:
# 루피
# 루피

# %%
a[0] = "나미"
print(a[0])
print(b[0])
# Out:
# 나미
# 나미
